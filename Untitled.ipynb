# %%
import pandas
import matplotlib as mpl

fichier =open("interventionscitoyendo.csv", "r")

df = pandas.DataFrame(fichier)
print(df.describe())
# Out:
#                                                         0
# count                                              164048
# unique                                             157787
# top     "Vol de véhicule à moteur","2019-12-09","jour"...
# freq                                                   38
